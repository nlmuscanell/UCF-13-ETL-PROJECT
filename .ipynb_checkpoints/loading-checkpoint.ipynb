# %% [markdown]
# # Fast Food Nutritional Database: Loading Notebook

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import create_engine, inspect
import pandas as pd

# %%
# Create the engine
engine = create_engine("sqlite:///Resources/fastfood_nutritional_info.db")

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['categories', 'menu_items', 'nutrition', 'restaurants']

# %%
#Save references to each table
Categories = Base.classes.categories
Menu_items = Base.classes.menu_items
Restaurants = Base.classes.restaurants
Nutrition = Base.classes.nutrition

# %%
# Create a session
session = Session(engine)

# %%
# Create a inspector
inspector = inspect(engine)

# %%
# Inspect Nurition
Nutrition_columns = inspector.get_columns('Nutrition')
for column in Nutrition_columns:
    print(column['name'], column["type"])
# Out:
# restaurant_id INTEGER
# category_id INTEGER
# item_id INTEGER
# serving_size_oz INTEGER
# calories INTEGER
# calories_from_fat INTEGER
# total_fat_g INTEGER
# total_fat_%_dv INTEGER
# saturated_fat_g INTEGER
# saturated_fat_%_dv INTEGER
# trans_fat_g INTEGER
# cholesterol_mg INTEGER
# cholesterol_%_dv INTEGER
# sodium_mg INTEGER
# sodium_%_dv INTEGER
# carbohydrates_g INTEGER
# carbohydrates_%_dv INTEGER
# dietary_fiber_g INTEGER
# dietary_fiber_% _dv INTEGER
# sugars_g INTEGER
# protein_g INTEGER
# vitamin_a_%_dv INTEGER
# vitamin_c_%_dv INTEGER
# calcium_%_dv INTEGER
# iron_%_dv INTEGER

# %%
# Inspect Restaurants
Restaurants_columns = inspector.get_columns('Restaurants')
for column in Restaurants_columns:
    print(column['name'], column["type"])
# Out:
# id INTEGER
# name TEXT

# %%
# Inspect Categories
Categories_columns = inspector.get_columns('Categories')
for column in Categories_columns:
    print(column['name'], column["type"])
# Out:
# category_name TEXT
# id INTEGER

# %%
# Inspect Menu Items
Items_columns = inspector.get_columns('Menu_items')
for column in Items_columns:
    print(column['name'], column["type"])
# Out:
# item_name TEXT
# id INTEGER

# %% [markdown]
# # Test Queries

# %%
# Query the nutrition table - list the average serving size for menu items in the database
nutrition_test = session.query(func.avg(Nutrition.serving_size_oz)).all()

print(f"The average serving size for a menu item (ounces) is {nutrition_test}.")
# Out:
# The average serving size for a menu item (ounces) is [(10.612996131645557,)].

# %%
# Query the restaurants table - list restaurant id numbers and names
restaurants_test = session.query(Restaurants.id, Restaurants.name).order_by(Restaurants.id.desc()).all()
restaurants_test
# Out:
# [(3000, 'starbucks'), (2000, 'subway'), (1000, 'mcdonalds')]

# %%
# Query the categories table - how many food categories are there in the database?
categories_test = session.query(func.count(Categories.category_name)).all()

print(f"There are {categories_test} food categories in the database.")
# Out:
# There are [(31,)] food categories in the database.

# %%
# Query the menu items table - find the second menu item in the database
items_test = session.query(Menu_items.item_name).all()

print(f"The second menu item in the database is {items_test[1]}.")
# Out:
# The second menu item in the database is ('8-Grain Roll',).

# %% [markdown]
# ## Queries joining together multiple tables

# %%
# Find the average fat content for salads (Categories + Nutrition tables) in the database 
# (categories + nutrition tables)

sel = [Categories.category_name, func.avg(Nutrition.total_fat_g)]

fat = session.query(*sel).filter(Nutrition.category_id==Categories.id).\
filter(Categories.category_name=="Salad").all()

print(f"Average fat(g): {fat}.")
# Out:
# Average fat(g): [('Salad', 14.61111111111111)].

# %%
# What are the average calories for menu items at each restaurant? (restaurants + nutrition tables)

sel = [Restaurants.name, Nutrition.restaurant_id, func.avg(Nutrition.calories)]

avg_calories = session.query(*sel).filter(Nutrition.restaurant_id==Restaurants.id).\
group_by(Restaurants.name).\
order_by(func.avg(Nutrition.calories).desc()).all()

avg_calories
# Out:
# [('mcdonalds', 1000, 368.2692307692308),
#  ('subway', 2000, 289.962962962963),
#  ('starbucks', 3000, 245.68169014084506)]

# %%
# What are the items that have the highest calories? (restaurants + menu_items + nutrition tables)

sel = [Restaurants.name, Menu_items.item_name, Nutrition.calories]

calories = session.query(*sel).filter(Nutrition.restaurant_id==Restaurants.id).\
order_by(Nutrition.calories.desc()).all()

calories
# Out:
# [('mcdonalds', '1% Low Fat Milk Jug', 1880),
#  ('mcdonalds', '8-Grain Roll', 1880),
#  ('mcdonalds', '9-Grain Honey Oat-Bread', 1880),
#  ('mcdonalds', '9-Grain Wheat-Bread', 1880),
#  ('mcdonalds', 'Almond Croissant', 1880),
#  ('mcdonalds', 'American-Cheese', 1880),
#  ('mcdonalds', 'Ancho Chipotle Chicken Panini', 1880),
#  ('mcdonalds', 'Apple Fritter', 1880),
#  ('mcdonalds', 'Apple Slices', 1880),
#  ('mcdonalds', 'Artisan Flatbread-Bread', 1880),
#  ('mcdonalds', 'BBQ Chicken Protein Box', 1880),
#  ('mcdonalds', 'BBQ Rib Signature Wrap-Wrap', 1880),
#  ('mcdonalds', 'BBQ Rib-Salad', 1880),
#  ('mcdonalds', 'BBQ Rib-Sandwich', 1880),
#  ('mcdonalds', 'Bacon Buffalo Ranch McChicken', 1880),
#  ('mcdonalds', 'Bacon Cheddar McChicken', 1880),
#  ('mcdonalds', 'Bacon Clubhouse Burger', 1880),
#  ('mcdonalds', 'Bacon Clubhouse Crispy Chicken Sandwich', 1880),
#  ('mcdonalds', 'Bacon Clubhouse Grilled Chicken Sandwich', 1880),
#  ('mcdonalds', 'Bacon Gouda & Egg Breakfast Sandwich', 1880),
#  ('mcdonalds', 'Bacon McDouble', 1880),
#  ('mcdonalds', 'Bacon, Egg & Cheese Bagel', 1880),
#  ('mcdonalds', 'Bacon, Egg & Cheese Bagel with Egg Whites', 1880),
#  ('mcdonalds', 'Bacon, Egg & Cheese Biscuit (Large Biscuit)', 1880),
#  ('mcdonalds', 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)', 1880),
#  ('mcdonalds',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)',
#   1880),
#  ('mcdonalds',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)',
#   1880),
#  ('mcdonalds', 'Bacon, Egg & Cheese McGriddles', 1880),
#  ('mcdonalds', 'Bacon, Egg & Cheese McGriddles with Egg Whites', 1880),
#  ('mcdonalds', 'Bacon, Egg & Cheese-Breakfast', 1880),
#  ('mcdonalds', 'Bacon-Extra', 1880),
#  ('mcdonalds', 'Bacon-Extras', 1880),
#  ('mcdonalds', 'Bacon-Protein', 1880),
#  ('mcdonalds', 'Baked Apple Pie', 1880),
#  ('mcdonalds', 'Banana Chocolate Smoothie-Grande 2% Milk', 1880),
#  ('mcdonalds', 'Banana Chocolate Smoothie-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Banana Chocolate Smoothie-Grande Soymilk', 1880),
#  ('mcdonalds', 'Banana Nut Bread', 1880),
#  ('mcdonalds', 'Banana Peppers-Veggies', 1880),
#  ('mcdonalds', 'Berry Trio Yogurt', 1880),
#  ('mcdonalds', 'Big Breakfast (Large Biscuit)', 1880),
#  ('mcdonalds', 'Big Breakfast (Regular Biscuit)', 1880),
#  ('mcdonalds', 'Big Breakfast with Egg Whites (Large Biscuit)', 1880),
#  ('mcdonalds', 'Big Breakfast with Egg Whites (Regular Biscuit)', 1880),
#  ('mcdonalds', 'Big Breakfast with Hotcakes (Large Biscuit)', 1880),
#  ('mcdonalds', 'Big Breakfast with Hotcakes (Regular Biscuit)', 1880),
#  ('mcdonalds',
#   'Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)',
#   1880),
#  ('mcdonalds',
#   'Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)',
#   1880),
#  ('mcdonalds', 'Big Mac', 1880),
#  ('mcdonalds', 'Birthday Cake Pop', 1880),
#  ('mcdonalds', 'Black Forest Ham, Egg & Cheese-Breakfast', 1880),
#  ('mcdonalds', 'Black Forest Ham-Salad', 1880),
#  ('mcdonalds', 'Black Forest Ham-Sandwich', 1880),
#  ('mcdonalds', 'Black Forest Ham-Wrap', 1880),
#  ('mcdonalds', 'Black Olives-Veggies', 1880),
#  ('mcdonalds', 'Blueberry Muffin with Yogurt and Honey', 1880),
#  ('mcdonalds', 'Blueberry Pomegranate Smoothie (Large)', 1880),
#  ('mcdonalds', 'Blueberry Pomegranate Smoothie (Medium)', 1880),
#  ('mcdonalds', 'Blueberry Pomegranate Smoothie (Small)', 1880),
#  ('mcdonalds', 'Blueberry Scone', 1880),
#  ('mcdonalds', 'Brewed Coffee-Grande Coffee', 1880),
#  ('mcdonalds', 'Brewed Coffee-Short Coffee', 1880),
#  ('mcdonalds', 'Brewed Coffee-Tall Coffee', 1880),
#  ('mcdonalds', 'Brewed Coffee-Venti Coffee', 1880),
#  ('mcdonalds', 'Buffalo Ranch McChicken', 1880),
#  ('mcdonalds', 'Burrata & Basil Pesto Small Sandwich', 1880),
#  ('mcdonalds', 'Butter Croissant', 1880),
#  ('mcdonalds', 'Butterfly Cookie', 1880),
#  ('mcdonalds', 'Caffè Americano-Grande', 1880),
#  ('mcdonalds', 'Caffè Americano-Short', 1880),
#  ('mcdonalds', 'Caffè Americano-Tall', 1880),
#  ('mcdonalds', 'Caffè Americano-Venti', 1880),
#  ('mcdonalds', 'Caffè Latte-Grande 2% Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Grande Soymilk', 1880),
#  ('mcdonalds', 'Caffè Latte-Short 2% Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Short Soymilk', 1880),
#  ('mcdonalds', 'Caffè Latte-Tall  2% Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Tall  Soymilk', 1880),
#  ('mcdonalds', 'Caffè Latte-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Venti 2% Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Latte-Venti Soymilk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Grande  2% Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Grande  Soymilk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Short 2% Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Short Soymilk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Tall 2% Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Tall Soymilk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Venti 2% Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Caffè Mocha (Without Whipped Cream)-Venti Soymilk', 1880),
#  ('mcdonalds', 'Cage-Free Eggs & Seasoned Grains Side Salad', 1880),
#  ('mcdonalds', 'Cappuccino-Grande 2% Milk', 1880),
#  ('mcdonalds', 'Cappuccino-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Cappuccino-Grande Soymilk', 1880),
#  ('mcdonalds', 'Cappuccino-Short  2% Milk', 1880),
#  ('mcdonalds', 'Cappuccino-Short  Soymilk', 1880),
#  ('mcdonalds', 'Cappuccino-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Cappuccino-Tall 2% Milk', 1880),
#  ('mcdonalds', 'Cappuccino-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Cappuccino-Tall Soymilk', 1880),
#  ('mcdonalds', 'Cappuccino-Venti  2% Milk', 1880),
#  ('mcdonalds', 'Cappuccino-Venti  Soymilk', 1880),
#  ('mcdonalds', 'Cappuccino-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Grande Soymilk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Grande Whole Milk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Tall Soymilk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Tall Whole Milk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Venti  Soymilk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel (Without Whipped Cream)-Venti Whole Milk', 1880),
#  ('mcdonalds', 'Caramel Apple Cookie-Extra', 1880),
#  ('mcdonalds', 'Caramel Apple Spice (Without Whipped Cream)-Grande', 1880),
#  ('mcdonalds', 'Caramel Apple Spice (Without Whipped Cream)-Short', 1880),
#  ('mcdonalds', 'Caramel Apple Spice (Without Whipped Cream)-Tall', 1880),
#  ('mcdonalds', 'Caramel Apple Spice (Without Whipped Cream)-Venti', 1880),
#  ('mcdonalds', 'Caramel Iced Coffee (Large)', 1880),
#  ('mcdonalds', 'Caramel Iced Coffee (Medium)', 1880),
#  ('mcdonalds', 'Caramel Iced Coffee (Small)', 1880),
#  ('mcdonalds', 'Caramel Latte (Large)', 1880),
#  ('mcdonalds', 'Caramel Latte (Medium)', 1880),
#  ('mcdonalds', 'Caramel Latte (Small)', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Grande 2% Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Grande Soymilk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Short 2% Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Short Soymilk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Tall  2% Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Tall  Soymilk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Venti 2% Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel Macchiato-Venti Soymilk', 1880),
#  ('mcdonalds', 'Caramel Mocha (Large)', 1880),
#  ('mcdonalds', 'Caramel Mocha (Medium)', 1880),
#  ('mcdonalds', 'Caramel Mocha (Small)', 1880),
#  ('mcdonalds', 'Caramel-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Caramel-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Cauliflower Fritter Curry Signature Wrap-Wrap', 1880),
#  ('mcdonalds', 'Cauliflower Tabbouleh Side Salad', 1880),
#  ('mcdonalds', 'Certified Gluten-Free Breakfast Sandwich', 1880),
#  ('mcdonalds', 'Cheddar**-Cheese', 1880),
#  ('mcdonalds', 'Cheese & Fruit Protein Box', 1880),
#  ('mcdonalds', 'Cheese Danish', 1880),
#  ('mcdonalds', 'Cheeseburger', 1880),
#  ('mcdonalds', 'Chewy Chocolate Cookie', 1880),
#  ('mcdonalds', 'Chicken & Bacon Ranch Melt-Sandwich', 1880),
#  ('mcdonalds', 'Chicken & Bacon Ranch Melt-Wrap', 1880),
#  ('mcdonalds', 'Chicken & Bacon Ranch-Salad', 1880),
#  ('mcdonalds',
#   'Chicken & Quinoa Protein Bowl with Black Beans and Greens',
#   1880),
#  ('mcdonalds', 'Chicken Artichoke on Ancient Grain Flatbread', 1880),
#  ('mcdonalds', 'Chicken BLT Salad Sandwich', 1880),
#  ('mcdonalds', 'Chicken Mango Curry-Sandwich', 1880),
#  ('mcdonalds', 'Chicken McNuggets (10 piece)', 1880),
#  ('mcdonalds', 'Chicken McNuggets (20 piece)', 1880),
#  ('mcdonalds', 'Chicken McNuggets (4 piece)', 1880),
#  ('mcdonalds', 'Chicken McNuggets (40 piece)', 1880),
#  ('mcdonalds', 'Chicken McNuggets (6 piece)', 1880),
#  ('mcdonalds', 'Chicken Tikka-Sandwich', 1880),
#  ('mcdonalds', 'Chicken Vindaloo-Sandwich', 1880),
#  ('mcdonalds', 'Chicken Wrap Protein Box', 1880),
#  ('mcdonalds', 'Chipotle BBQ Snack Wrap (Crispy Chicken)', 1880),
#  ('mcdonalds', 'Chipotle BBQ Snack Wrap (Grilled Chicken)', 1880),
#  ('mcdonalds', 'Chipotle Southwest Steak & Cheese-Wrap', 1880),
#  ('mcdonalds', 'Chipotle Southwest-Sauces', 1880),
#  ('mcdonalds', 'Chocolate Cake Pop', 1880),
#  ('mcdonalds', 'Chocolate Chip Cookie', 1880),
#  ('mcdonalds', 'Chocolate Chip Cookie Dough Cake Pop', 1880),
#  ('mcdonalds', 'Chocolate Chip Cookie-Extra', 1880),
#  ('mcdonalds', 'Chocolate Chip with M&M’s ®-Extra', 1880),
#  ('mcdonalds', 'Chocolate Chunk Cookie-Extra', 1880),
#  ('mcdonalds', 'Chocolate Chunk Muffin', 1880),
#  ('mcdonalds', 'Chocolate Croissant', 1880),
#  ('mcdonalds', 'Chocolate Hazelnut Croissant', 1880),
#  ('mcdonalds', 'Chocolate Marble Loaf Cake', 1880),
#  ('mcdonalds', 'Chocolate Shake (Large)', 1880),
#  ('mcdonalds', 'Chocolate Shake (Medium)', 1880),
#  ('mcdonalds', 'Chocolate Shake (Small)', 1880),
#  ('mcdonalds', 'Chonga Bagel', 1880),
#  ('mcdonalds', 'Cinnamon Melts', 1880),
#  ('mcdonalds', 'Cinnamon Morning Bun', 1880),
#  ('mcdonalds', 'Cinnamon Raisin Bagel', 1880),
#  ('mcdonalds', 'Classic Coffee Cake', 1880),
#  ('mcdonalds', 'Classic Tuna-Sandwich', 1880),
#  ('mcdonalds', 'Classic Whole-Grain Oatmeal', 1880),
#  ('mcdonalds', 'Coca-Cola Classic (Child)', 1880),
#  ('mcdonalds', 'Coca-Cola Classic (Large)', 1880),
#  ('mcdonalds', 'Coca-Cola Classic (Medium)', 1880),
#  ('mcdonalds', 'Coca-Cola Classic (Small)', 1880),
#  ('mcdonalds', 'Coffee (Large)', 1880),
#  ('mcdonalds', 'Coffee (Medium)', 1880),
#  ('mcdonalds', 'Coffee (Small)', 1880),
#  ('mcdonalds', 'Coffee-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Coffee-Grande Soymilk', 1880),
#  ('mcdonalds', 'Coffee-Grande Whole Milk', 1880),
#  ('mcdonalds', 'Coffee-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Coffee-Tall Soymilk', 1880),
#  ('mcdonalds', 'Coffee-Tall Whole Milk', 1880),
#  ('mcdonalds', 'Coffee-Venti  Soymilk', 1880),
#  ('mcdonalds', 'Coffee-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Coffee-Venti Whole Milk', 1880),
#  ('mcdonalds', 'Cold Cut Combo-Salad', 1880),
#  ('mcdonalds', 'Cold Cut Combo-Sandwich', 1880),
#  ('mcdonalds', 'Cold Cut Combo-Wrap', 1880),
#  ('mcdonalds', 'Cookie Butter Bar', 1880),
#  ('mcdonalds', 'Cranberry Orange Scone', 1880),
#  ('mcdonalds', 'Cripsy Cauliflower Ranch Signature Wrap-Wrap', 1880),
#  ('mcdonalds', 'Cubano Sandwich', 1880),
#  ('mcdonalds', 'Cucumbers-Veggies', 1880),
#  ('mcdonalds', 'Daily Double', 1880),
#  ('mcdonalds', 'Dark Chocolate Cherry Cookie-Extra', 1880),
#  ('mcdonalds', 'Dasani Water Bottle', 1880),
#  ('mcdonalds', "Devil's Food Doughnut", 1880),
#  ('mcdonalds', 'Diet Coke (Child)', 1880),
#  ('mcdonalds', 'Diet Coke (Large)', 1880),
#  ('mcdonalds', 'Diet Coke (Medium)', 1880),
#  ('mcdonalds', 'Diet Coke (Small)', 1880),
#  ('mcdonalds', 'Diet Dr Pepper (Child)', 1880),
#  ('mcdonalds', 'Diet Dr Pepper (Large)', 1880),
#  ('mcdonalds', 'Diet Dr Pepper (Medium)', 1880),
#  ('mcdonalds', 'Diet Dr Pepper (Small)', 1880),
#  ('mcdonalds', 'Double Cheeseburger', 1880),
#  ('mcdonalds', 'Double Chocolate Brownie', 1880),
#  ('mcdonalds', 'Double Chocolate Chunk Brownie', 1880),
#  ('mcdonalds', 'Double Chocolate Loaf Cake', 1880),
#  ('mcdonalds', 'Double Chocolate-Extra', 1880),
#  ('mcdonalds', 'Double Quarter Pounder with Cheese', 1880),
#  ('mcdonalds', 'Double-Smoked Bacon Cheddar & Egg Sandwich', 1880),
#  ('mcdonalds', 'Dr Pepper (Child)', 1880),
#  ('mcdonalds', 'Dr Pepper (Large)', 1880),
#  ('mcdonalds', 'Dr Pepper (Medium)', 1880),
#  ('mcdonalds', 'Dr Pepper (Small)', 1880),
#  ('mcdonalds', 'Egg & Cheese-Breakfast', 1880),
#  ('mcdonalds', 'Egg McMuffin', 1880),
#  ('mcdonalds', 'Egg Salad Sandwich', 1880),
#  ('mcdonalds', 'Egg White Delight', 1880),
#  ('mcdonalds', 'Eggs & Cheese Protein Box', 1880),
#  ('mcdonalds', 'Espresso-Doppio', 1880),
#  ('mcdonalds', 'Espresso-Solo', 1880),
#  ('mcdonalds', "Everybody's Favorite - Bantam Bagel (2 Pack)", 1880),
#  ('mcdonalds', 'Everything Bagel with Cheese', 1880),
#  ('mcdonalds', "Farmers' Market Protein Box", 1880),
#  ('mcdonalds', 'Fat Free Chocolate Milk Jug', 1880),
#  ('mcdonalds', 'Filet-O-Fish', 1880),
#  ('mcdonalds', 'Frappuccino® Cookie Straw', 1880),
#  ('mcdonalds', 'Frappé Caramel (Large)', 1880),
#  ('mcdonalds', 'Frappé Caramel (Medium)', 1880),
#  ('mcdonalds', 'Frappé Caramel (Small)', 1880),
#  ('mcdonalds', 'Frappé Chocolate Chip (Large)', 1880),
#  ('mcdonalds', 'Frappé Chocolate Chip (Medium)', 1880),
#  ('mcdonalds', 'Frappé Chocolate Chip (Small)', 1880),
#  ('mcdonalds', 'Frappé Mocha (Large)', 1880),
#  ('mcdonalds', 'Frappé Mocha (Medium)', 1880),
#  ('mcdonalds', 'Frappé Mocha (Small)', 1880),
#  ('mcdonalds', 'French Toast - Bantam Bagels (2 Pack)', 1880),
#  ('mcdonalds', 'French Vanilla Iced Coffee (Large)', 1880),
#  ('mcdonalds', 'French Vanilla Iced Coffee (Medium)', 1880),
#  ('mcdonalds', 'French Vanilla Iced Coffee (Small)', 1880),
#  ('mcdonalds', 'French Vanilla Latte (Large)', 1880),
#  ('mcdonalds', 'French Vanilla Latte (Medium)', 1880),
#  ('mcdonalds', 'French Vanilla Latte (Small)', 1880),
#  ('mcdonalds', 'Fresh Blueberries and Honey Greek Yogurt Parfait', 1880),
#  ('mcdonalds', 'Fruit & Maple Oatmeal', 1880),
#  ('mcdonalds', 'Fruit & Maple Oatmeal without Brown Sugar', 1880),
#  ('mcdonalds', "Fruit 'n Yogurt Parfait", 1880),
#  ('mcdonalds', 'Garden Greens & Shaved Parmesan Side Salad', 1880),
#  ('mcdonalds', 'Genoa Salami-Sandwich', 1880),
#  ('mcdonalds', 'Gluten-Free Marshmallow Dream Bar', 1880),
#  ('mcdonalds', 'Green Goddess Avocado Salad', 1880),
#  ('mcdonalds', 'Green Peppers-Veggies', 1880),
#  ('mcdonalds', 'Guacamole-Extras', 1880),
#  ('mcdonalds', 'Ham & Cheese Croissant', 1880),
#  ('mcdonalds', 'Ham & Jack Slider-Sandwich', 1880),
#  ('mcdonalds', 'Hamburger', 1880),
#  ('mcdonalds', 'Hash Brown', 1880),
#  ('mcdonalds', 'Hazelnut Iced Coffee (Large)', 1880),
#  ('mcdonalds', 'Hazelnut Iced Coffee (Medium)', 1880),
#  ('mcdonalds', 'Hazelnut Iced Coffee (Small)', 1880),
#  ('mcdonalds', 'Hazelnut Latte (Large)', 1880),
#  ('mcdonalds', 'Hazelnut Latte (Medium)', 1880),
#  ('mcdonalds', 'Hazelnut Latte (Small)', 1880),
#  ('mcdonalds', 'Hearty Blueberry Oatmeal', 1880),
#  ('mcdonalds', 'Hearty Italian**-Bread', 1880),
#  ('mcdonalds', 'Herbed Chicken & Fig Spread Small Sandwich', 1880),
#  ('mcdonalds', 'Homestyle Chicken & Double-Smoked Bacon', 1880),
#  ('mcdonalds', 'Honey BBQ Sriracha Chicken Sandwich', 1880),
#  ('mcdonalds', 'Honey Mustard Snack Wrap (Crispy Chicken)', 1880),
#  ('mcdonalds', 'Honey Mustard Snack Wrap (Grilled Chicken)', 1880),
#  ('mcdonalds', 'Honey Mustard**-Sauces', 1880),
#  ('mcdonalds', 'Hot Caramel Sundae', 1880),
#  ('mcdonalds', 'Hot Chocolate (Large)', 1880),
#  ('mcdonalds', 'Hot Chocolate (Medium)', 1880),
#  ('mcdonalds', 'Hot Chocolate (Small)', 1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Grande 2% Milk', 1880),
#  ('mcdonalds',
#   'Hot Chocolate (Without Whipped Cream)-Grande Nonfat Milk',
#   1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Grande Soymilk', 1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Short 2% Milk', 1880),
#  ('mcdonalds',
#   'Hot Chocolate (Without Whipped Cream)-Short Nonfat Milk',
#   1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Short Soymilk', 1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Tall  2% Milk', 1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Tall  Soymilk', 1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Venti  2% Milk', 1880),
#  ('mcdonalds', 'Hot Chocolate (Without Whipped Cream)-Venti  Soymilk', 1880),
#  ('mcdonalds',
#   'Hot Chocolate (Without Whipped Cream)-Venti Nonfat Milk',
#   1880),
#  ('mcdonalds', 'Hot Chocolate with Nonfat Milk (Large)', 1880),
#  ('mcdonalds', 'Hot Chocolate with Nonfat Milk (Medium)', 1880),
#  ('mcdonalds', 'Hot Chocolate with Nonfat Milk (Small)', 1880),
#  ('mcdonalds', 'Hot Fudge Sundae', 1880),
#  ('mcdonalds', 'Hotcakes', 1880),
#  ('mcdonalds', 'Hotcakes and Sausage', 1880),
#  ('mcdonalds', 'Ice Cream Cone Sugar Cookie', 1880),
#  ('mcdonalds', 'Iced Brewed Coffee (With Classic Syrup)-Grande', 1880),
#  ('mcdonalds', 'Iced Brewed Coffee (With Classic Syrup)-Tall', 1880),
#  ('mcdonalds', 'Iced Brewed Coffee (With Classic Syrup)-Venti', 1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Grande 2% Milk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Grande Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Grande Soymilk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Tall  2% Milk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Tall Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Tall Soymilk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Venti  2% Milk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Venti  Soymilk',
#   1880),
#  ('mcdonalds',
#   'Iced Brewed Coffee (With Milk & Classic Syrup)-Venti Nonfat Milk',
#   1880),
#  ('mcdonalds', 'Iced Caramel Mocha (Large)', 1880),
#  ('mcdonalds', 'Iced Caramel Mocha (Medium)', 1880),
#  ('mcdonalds', 'Iced Caramel Mocha (Small)', 1880),
#  ('mcdonalds',
#   'Iced Coffee with Sugar Free French Vanilla Syrup (Large)',
#   1880),
#  ('mcdonalds',
#   'Iced Coffee with Sugar Free French Vanilla Syrup (Medium)',
#   1880),
#  ('mcdonalds',
#   'Iced Coffee with Sugar Free French Vanilla Syrup (Small)',
#   1880),
#  ('mcdonalds', 'Iced Lemon Pound Cake', 1880),
#  ('mcdonalds', 'Iced Mocha (Large)', 1880),
#  ('mcdonalds', 'Iced Mocha (Medium)', 1880),
#  ('mcdonalds', 'Iced Mocha (Small)', 1880),
#  ('mcdonalds', 'Iced Mocha with Nonfat Milk (Large)', 1880),
#  ('mcdonalds', 'Iced Mocha with Nonfat Milk (Medium)', 1880),
#  ('mcdonalds', 'Iced Mocha with Nonfat Milk (Small)', 1880),
#  ('mcdonalds', 'Iced Nonfat Caramel Mocha (Large)', 1880),
#  ('mcdonalds', 'Iced Nonfat Caramel Mocha (Medium)', 1880),
#  ('mcdonalds', 'Iced Nonfat Caramel Mocha (Small)', 1880),
#  ('mcdonalds', 'Iced Tea (Child)', 1880),
#  ('mcdonalds', 'Iced Tea (Large)', 1880),
#  ('mcdonalds', 'Iced Tea (Medium)', 1880),
#  ('mcdonalds', 'Iced Tea (Small)', 1880),
#  ('mcdonalds', 'Italian B.M.T. ®-Salad', 1880),
#  ('mcdonalds', 'Italian B.M.T. ®-Wrap', 1880),
#  ('mcdonalds', 'Italian B.M.T.®-Sandwich', 1880),
#  ('mcdonalds', 'Italian Herbs & Cheese-Bread', 1880),
#  ('mcdonalds', 'Italian Spice Slider-Sandwich', 1880),
#  ('mcdonalds', 'Italian-Bread', 1880),
#  ('mcdonalds', 'Italian-Style Ham & Spicy Salami', 1880),
#  ('mcdonalds', 'Jalapenos-Veggies', 1880),
#  ('mcdonalds', 'Jalapeño Cheese-Bread', 1880),
#  ('mcdonalds', 'Jalapeño Double', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Grande Soymilk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Grande Whole Milk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Tall Soymilk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Tall Whole Milk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Venti  Whole Milk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Java Chip (Without Whipped Cream)-Venti Soymilk', 1880),
#  ('mcdonalds', 'Java Chip-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Java Chip-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Java Chip-Venti Nonfat Milk', 1880),
#  ('mcdonalds', "Justin's Chocolate Hazelnut Butter", 1880),
#  ('mcdonalds', "Justin's Classic Almond Butter", 1880),
#  ('mcdonalds', 'Kids French Fries', 1880),
#  ('mcdonalds', 'Kids Ice Cream Cone', 1880),
#  ('mcdonalds', 'Large French Fries', 1880),
#  ('mcdonalds', 'Latte (Large)', 1880),
#  ('mcdonalds', 'Latte (Medium)', 1880),
#  ('mcdonalds', 'Latte (Small)', 1880),
#  ('mcdonalds', 'Latte with Sugar Free French Vanilla Syrup (Large)', 1880),
#  ('mcdonalds', 'Latte with Sugar Free French Vanilla Syrup (Medium)', 1880),
#  ('mcdonalds', 'Latte with Sugar Free French Vanilla Syrup (Small)', 1880),
#  ('mcdonalds', 'Lemon Chiffon Yogurt', 1880),
#  ('mcdonalds', 'Lentils & Vegetable Protein Bowl with Brown Rice', 1880),
#  ('mcdonalds', 'Lettuce-Veggies', 1880),
#  ('mcdonalds', 'Light Blended Coffee-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Light Blended Coffee-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Light Blended Coffee-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Light Mayonnaise-Sauces', 1880),
#  ('mcdonalds', 'Little Cheesesteak Slider-Sandwich', 1880),
#  ('mcdonalds', 'Little Turkey Slider-Sandwich', 1880),
#  ('mcdonalds', 'Mango Pineapple Smoothie (Large)', 1880),
#  ('mcdonalds', 'Mango Pineapple Smoothie (Medium)', 1880),
#  ('mcdonalds', 'Mango Pineapple Smoothie (Small)', 1880),
#  ('mcdonalds', 'McChicken', 1880),
#  ('mcdonalds', 'McDouble', 1880),
#  ('mcdonalds', 'McFlurry with M&M’s Candies (Medium)', 1880),
#  ('mcdonalds', 'McFlurry with M&M’s Candies (Small)', 1880),
#  ('mcdonalds', 'McFlurry with M&M’s Candies (Snack)', 1880),
#  ('mcdonalds', 'McFlurry with Oreo Cookies (Medium)', 1880),
#  ('mcdonalds', 'McFlurry with Oreo Cookies (Small)', 1880),
#  ('mcdonalds', 'McFlurry with Oreo Cookies (Snack)', 1880),
#  ('mcdonalds', "McFlurry with Reese's Peanut Butter Cups (Medium)", 1880),
#  ('mcdonalds', "McFlurry with Reese's Peanut Butter Cups (Snack)", 1880),
#  ('mcdonalds', 'McRib', 1880),
#  ('mcdonalds', 'Meatball Marinara-Salad', 1880),
#  ('mcdonalds', 'Meatball Marinara-Sandwich', 1880),
#  ('mcdonalds', 'Meatball Marinara-Wrap', 1880),
#  ('mcdonalds', 'Medium French Fries', 1880),
#  ('mcdonalds', 'Michigan Cherry Oat Bar', 1880),
#  ('mcdonalds', 'Mini 9-Grain Wheat-Bread', 1880),
#  ('mcdonalds', 'Mini Italian-Bread', 1880),
#  ('mcdonalds', 'Minute Maid 100% Apple Juice Box', 1880),
#  ('mcdonalds', 'Minute Maid Orange Juice (Large)', 1880),
#  ('mcdonalds', 'Minute Maid Orange Juice (Medium)', 1880),
#  ('mcdonalds', 'Minute Maid Orange Juice (Small)', 1880),
#  ('mcdonalds', 'Mocha (Large)', 1880),
#  ('mcdonalds', 'Mocha (Medium)', 1880),
#  ('mcdonalds', 'Mocha (Small)', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Grande Soymilk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Grande Whole Milk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Tall Soymilk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Tall Whole Milk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Venti Soymilk', 1880),
#  ('mcdonalds', 'Mocha (Without Whipped Cream)-Venti Whole Milk', 1880),
#  ('mcdonalds', 'Mocha with Nonfat Milk (Large)', 1880),
#  ('mcdonalds', 'Mocha with Nonfat Milk (Medium)', 1880),
#  ('mcdonalds', 'Mocha with Nonfat Milk (Small)', 1880),
#  ('mcdonalds', 'Mocha-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Mocha-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Mocha-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Monterey Cheddar**-Bread', 1880),
#  ('mcdonalds', 'Monterey Cheddar-Cheese', 1880),
#  ('mcdonalds', 'Multigrain Bagel', 1880),
#  ('mcdonalds', 'Nonfat Caramel Latte (Large)', 1880),
#  ('mcdonalds', 'Nonfat Caramel Latte (Medium)', 1880),
#  ('mcdonalds', 'Nonfat Caramel Latte (Small)', 1880),
#  ('mcdonalds', 'Nonfat Caramel Mocha (Large)', 1880),
#  ('mcdonalds', 'Nonfat Caramel Mocha (Medium)', 1880),
#  ('mcdonalds', 'Nonfat Caramel Mocha (Small)', 1880),
#  ('mcdonalds', 'Nonfat French Vanilla Latte (Large)', 1880),
#  ('mcdonalds', 'Nonfat French Vanilla Latte (Medium)', 1880),
#  ('mcdonalds', 'Nonfat French Vanilla Latte (Small)', 1880),
#  ('mcdonalds', 'Nonfat Hazelnut Latte (Large)', 1880),
#  ('mcdonalds', 'Nonfat Hazelnut Latte (Medium)', 1880),
#  ('mcdonalds', 'Nonfat Hazelnut Latte (Small)', 1880),
#  ('mcdonalds', 'Nonfat Latte (Large)', 1880),
#  ('mcdonalds', 'Nonfat Latte (Medium)', 1880),
#  ('mcdonalds', 'Nonfat Latte (Small)', 1880),
#  ('mcdonalds',
#   'Nonfat Latte with Sugar Free French Vanilla Syrup (Large)',
#   1880),
#  ('mcdonalds',
#   'Nonfat Latte with Sugar Free French Vanilla Syrup (Medium)',
#   1880),
#  ('mcdonalds',
#   'Nonfat Latte with Sugar Free French Vanilla Syrup (Small)',
#   1880),
#  ('mcdonalds', 'Oatmeal Cookie', 1880),
#  ('mcdonalds', 'Oatmeal Raisin Cookie', 1880),
#  ('mcdonalds', 'Oatmeal Raisin Cookie-Extra', 1880),
#  ('mcdonalds', 'Octopus Cookie', 1880),
#  ('mcdonalds', 'Oil-Sauces', 1880),
#  ('mcdonalds', 'Old-Fashioned Glazed Doughnut', 1880),
#  ('mcdonalds', 'Orange Mango Banana Smoothie-Tall 2% Milk', 1880),
#  ('mcdonalds', 'Orange Mango Banana Smoothie-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Orange Mango Banana Smoothie-Tall Soymilk', 1880),
#  ('mcdonalds', 'Organic Avocado (Spread)', 1880),
#  ('mcdonalds', 'Oven Roasted Chicken-Salad', 1880),
#  ('mcdonalds', 'Oven Roasted Chicken-Sandwich', 1880),
#  ('mcdonalds', 'Oven Roasted Chicken-Wrap', 1880),
#  ('mcdonalds', 'PB&J Protein Box', 1880),
#  ('mcdonalds', 'Paneer Tikka-Sandwich', 1880),
#  ('mcdonalds', 'Parmesan Cheese-Seasonings', 1880),
#  ('mcdonalds', 'Parmesan Oregano**-Bread', 1880),
#  ('mcdonalds', 'Peanut butter cup cookie', 1880),
#  ('mcdonalds', 'Pecan Tart', 1880),
#  ('mcdonalds', 'Pepperjack**-Cheese', 1880),
#  ('mcdonalds', 'Pepperoni-Extra', 1880),
#  ('mcdonalds', 'Pepperoni-Extras', 1880),
#  ('mcdonalds', 'Petite Vanilla Bean Scone', 1880),
#  ('mcdonalds', 'Pickles-Veggies', 1880),
#  ('mcdonalds', 'Pirate Cake Pop', 1880),
#  ('mcdonalds', 'Plain Bagel', 1880),
#  ('mcdonalds', 'Premium Bacon Ranch Salad (without Chicken)', 1880),
#  ('mcdonalds', 'Premium Bacon Ranch Salad with Crispy Chicken', 1880),
#  ('mcdonalds', 'Premium Bacon Ranch Salad with Grilled Chicken', 1880),
#  ('mcdonalds', 'Premium Crispy Chicken Classic Sandwich', 1880),
#  ('mcdonalds', 'Premium Crispy Chicken Club Sandwich', 1880),
#  ('mcdonalds', 'Premium Crispy Chicken Ranch BLT Sandwich', 1880),
#  ('mcdonalds', 'Premium Grilled Chicken Classic Sandwich', 1880),
#  ('mcdonalds', 'Premium Grilled Chicken Club Sandwich', 1880),
#  ('mcdonalds', 'Premium Grilled Chicken Ranch BLT Sandwich', 1880),
#  ('mcdonalds', 'Premium McWrap Chicken & Bacon (Crispy Chicken)', 1880),
#  ('mcdonalds', 'Premium McWrap Chicken & Bacon (Grilled Chicken)', 1880),
#  ('mcdonalds', 'Premium McWrap Chicken & Ranch (Crispy Chicken)', 1880),
#  ('mcdonalds', 'Premium McWrap Chicken & Ranch (Grilled Chicken)', 1880),
#  ('mcdonalds', 'Premium McWrap Chicken Sweet Chili (Crispy Chicken)', 1880),
#  ('mcdonalds', 'Premium McWrap Chicken Sweet Chili (Grilled Chicken)', 1880),
#  ('mcdonalds', 'Premium McWrap Southwest Chicken (Crispy Chicken)', 1880),
#  ('mcdonalds', 'Premium McWrap Southwest Chicken (Grilled Chicken)', 1880),
#  ('mcdonalds', 'Premium Southwest Salad (without Chicken)', 1880),
#  ('mcdonalds', 'Premium Southwest Salad with Crispy Chicken', 1880),
#  ('mcdonalds', 'Premium Southwest Salad with Grilled Chicken', 1880),
#  ('mcdonalds', 'Provolone-Cheese', 1880),
#  ('mcdonalds', 'Pumpkin Bread', 1880),
#  ('mcdonalds', 'Quarter Pounder Deluxe', 1880),
#  ('mcdonalds', 'Quarter Pounder with Bacon & Cheese', 1880),
#  ('mcdonalds', 'Quarter Pounder with Bacon Habanero Ranch', 1880),
#  ('mcdonalds', 'Quarter Pounder with Cheese', 1880),
#  ('mcdonalds', 'Ranch Snack Wrap (Crispy Chicken)', 1880),
#  ('mcdonalds', 'Ranch Snack Wrap (Grilled Chicken)', 1880),
#  ('mcdonalds', 'Ranch-Sauces', 1880),
#  ('mcdonalds', 'Raspberry Cheesecake Cookie-Extra', 1880),
#  ('mcdonalds', 'Raspberry Lemonade Cookie-Extra', 1880),
#  ('mcdonalds', 'Raspberry Swirl Loaf Cake', 1880),
#  ('mcdonalds', 'Raspberry Whoopie Pie', 1880),
#  ('mcdonalds', 'Red Onions-Veggies', 1880),
#  ('mcdonalds', 'Red Wine Vinegar-Sauces', 1880),
#  ('mcdonalds', 'Reduced-Fat Cinnamon Swirl Coffee Cake', 1880),
#  ('mcdonalds',
#   'Reduced-Fat Turkey Bacon & Cage Free Egg White Breakfast Sandwich',
#   1880),
#  ('mcdonalds', 'Regular Iced Coffee (Large)', 1880),
#  ('mcdonalds', 'Regular Iced Coffee (Medium)', 1880),
#  ('mcdonalds', 'Regular Iced Coffee (Small)', 1880),
#  ('mcdonalds', 'Regular Mayonnaise-Sauces', 1880),
#  ('mcdonalds', 'Roast Beef-Salad', 1880),
#  ('mcdonalds', 'Roast Beef-Sandwich', 1880),
#  ('mcdonalds', 'Roast Beef-Wrap', 1880),
#  ('mcdonalds', 'Roasted Carrot & Kale Side Salad', 1880),
#  ('mcdonalds', 'Roasted Garlic-Bread', 1880),
#  ('mcdonalds', 'Roasted Tomato & Mozzarella Panini', 1880),
#  ('mcdonalds', 'Roasted Turkey & Dill Havarti Sandwich', 1880),
#  ('mcdonalds', 'Rosemary & Sea Salt-Bread', 1880),
#  ('mcdonalds', 'Rotisserie-Style Chicken-Salad', 1880),
#  ('mcdonalds', 'Rotisserie-Style Chicken-Sandwich', 1880),
#  ('mcdonalds', 'Rotisserie-Style Chicken-Wrap', 1880),
#  ('mcdonalds', "S'mores Bar", 1880),
#  ('mcdonalds', "S'mores Bar Multipack", 1880),
#  ('mcdonalds', 'Sausage Biscuit (Large Biscuit)', 1880),
#  ('mcdonalds', 'Sausage Biscuit (Regular Biscuit)', 1880),
#  ('mcdonalds', 'Sausage Biscuit with Egg (Large Biscuit)', 1880),
#  ('mcdonalds', 'Sausage Biscuit with Egg (Regular Biscuit)', 1880),
#  ('mcdonalds', 'Sausage Biscuit with Egg Whites (Large Biscuit)', 1880),
#  ('mcdonalds', 'Sausage Biscuit with Egg Whites (Regular Biscuit)', 1880),
#  ('mcdonalds', 'Sausage Burrito', 1880),
#  ('mcdonalds', 'Sausage Cheddar & Egg Breakfast Sandwich', 1880),
#  ('mcdonalds', 'Sausage McGriddles', 1880),
#  ('mcdonalds', 'Sausage McMuffin', 1880),
#  ('mcdonalds', 'Sausage McMuffin with Egg', 1880),
#  ('mcdonalds', 'Sausage McMuffin with Egg Whites', 1880),
#  ('mcdonalds', 'Sausage, Egg & Cheese McGriddles', 1880),
#  ('mcdonalds', 'Sausage, Egg & Cheese McGriddles with Egg Whites', 1880),
#  ('mcdonalds', 'Savory Caesar**-Sauces', 1880),
#  ('mcdonalds', 'Savory Rotisserie-Style Chicken Caesar-Wrap', 1880),
#  ('mcdonalds', 'Seared Steak & Cheddar Sandwich', 1880),
#  ('mcdonalds', 'Seared Steak Egg & Tomatillo Wrap', 1880),
#  ('mcdonalds', 'Seasonal Fruit Blend', 1880),
#  ('mcdonalds', 'Shaken Iced Tazo® Tea (With Classic Syrup)-Grande', 1880),
#  ('mcdonalds', 'Shaken Iced Tazo® Tea (With Classic Syrup)-Tall', 1880),
#  ('mcdonalds', 'Shaken Iced Tazo® Tea (With Classic Syrup)-Venti', 1880),
#  ('mcdonalds',
#   'Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)-Grande',
#   1880),
#  ('mcdonalds',
#   'Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)-Tall',
#   1880),
#  ('mcdonalds',
#   'Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)-Venti',
#   1880),
#  ('mcdonalds', 'Shamrock Shake (Large)', 1880),
#  ('mcdonalds', 'Shamrock Shake (Medium)', 1880),
#  ('mcdonalds', 'Shredded Mozzarella-Cheese', 1880),
#  ('mcdonalds', 'Side Salad', 1880),
#  ('mcdonalds', 'Skinny Latte (Any Flavour)-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Skinny Latte (Any Flavour)-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Skinny Latte (Any Flavour)-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Skinny Latte (Any Flavour)-Venti Nonfat Milk', 1880),
#  ('mcdonalds',
#   "Slow-Roasted Ham & Beecher's Flagship Cheese Small Sandwich",
#   1880),
#  ('mcdonalds', 'Slow-Roasted Ham Swiss & Egg Breakfast Sandwich', 1880),
#  ('mcdonalds', 'Small French Fries', 1880),
#  ('mcdonalds', 'Smoked Mozzarella & Roasted Pepper Sandwich', 1880),
#  ('mcdonalds', 'Smoked Turkey Protein Box', 1880),
#  ('mcdonalds', 'Sous Vide Egg Bites: Bacon & Gruyere', 1880),
#  ('mcdonalds', 'Sous Vide Egg Bites: Egg White & Red Pepper', 1880),
#  ('mcdonalds', 'Southern Style Chicken Biscuit (Large Biscuit)', 1880),
#  ('mcdonalds', 'Southern Style Chicken Biscuit (Regular Biscuit)', 1880),
#  ('mcdonalds', 'Southern Style Crispy Chicken Sandwich', 1880),
#  ('mcdonalds', 'Southwest Chicken Club-Sandwich', 1880),
#  ('mcdonalds', 'Southwest Chipotle Chicken Club-Salad', 1880),
#  ('mcdonalds', 'Spicy Brown Mustard-Sauces', 1880),
#  ('mcdonalds', 'Spicy Chorizo  Monterey Jack & Egg Breakfast Sandwich', 1880),
#  ('mcdonalds', 'Spicy Italian-Salad', 1880),
#  ('mcdonalds', 'Spicy Italian-Sandwich', 1880),
#  ('mcdonalds', 'Spicy Italian-Wrap', 1880),
#  ('mcdonalds', 'Spinach Feta & Cage Free Egg White Breakfast Wrap', 1880),
#  ('mcdonalds', 'Spinach Wrap-Bread', 1880),
#  ('mcdonalds', 'Spinach-Veggies', 1880),
#  ('mcdonalds', 'Sprite (Child)', 1880),
#  ('mcdonalds', 'Sprite (Large)', 1880),
#  ('mcdonalds', 'Sprite (Medium)', 1880),
#  ('mcdonalds', 'Sprite (Small)', 1880),
#  ('mcdonalds', 'Sprouted Grain Vegan Bagel', 1880),
#  ('mcdonalds', 'Starbucks Chocolate Chip Cookie', 1880),
#  ('mcdonalds', 'Steak & Cheese-Salad', 1880),
#  ('mcdonalds', 'Steak & Cheese-Sandwich', 1880),
#  ('mcdonalds', 'Steak & Egg Biscuit (Regular Biscuit)', 1880),
#  ('mcdonalds', 'Steak & Egg McMuffin', 1880),
#  ('mcdonalds', 'Steak Club Salad-Salad', 1880),
#  ('mcdonalds', 'Steak Club-Sandwich', 1880),
#  ('mcdonalds', 'Steak, Egg & Cheese Bagel', 1880),
#  ('mcdonalds', 'Steak, Egg & Cheese-Breakfast', 1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Grande Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Grande Soymilk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Grande Whole Milk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Tall  Soymilk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Tall  Whole Milk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Tall Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Venti  Soymilk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Venti Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Strawberries & Crème (Without Whipped Cream)-Venti Whole Milk',
#   1880),
#  ('mcdonalds', 'Strawberries & Jam Sandwich', 1880),
#  ('mcdonalds', 'Strawberry Banana Smoothie (Large)', 1880),
#  ('mcdonalds', 'Strawberry Banana Smoothie (Medium)', 1880),
#  ('mcdonalds', 'Strawberry Banana Smoothie (Small)', 1880),
#  ('mcdonalds', 'Strawberry Banana Smoothie-Grande 2% Milk', 1880),
#  ('mcdonalds', 'Strawberry Banana Smoothie-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Strawberry Banana Smoothie-Grande Soymilk', 1880),
#  ('mcdonalds', 'Strawberry Cake Pop', 1880),
#  ('mcdonalds', 'Strawberry Shake (Large)', 1880),
#  ('mcdonalds', 'Strawberry Shake (Medium)', 1880),
#  ('mcdonalds', 'Strawberry Shake (Small)', 1880),
#  ('mcdonalds', 'Strawberry Sundae', 1880),
#  ('mcdonalds', 'Subway Club®-Salad', 1880),
#  ('mcdonalds', 'Subway Club®-Sandwich', 1880),
#  ('mcdonalds', 'Subway Club®-Wrap', 1880),
#  ('mcdonalds', 'Subway® Vinaigrette-Sauces', 1880),
#  ('mcdonalds', 'Sugar Cookie-Extra', 1880),
#  ('mcdonalds', 'Sweet Onion Chicken Teriyaki-Salad', 1880),
#  ('mcdonalds', 'Sweet Onion Chicken Teriyaki-Sandwich', 1880),
#  ('mcdonalds', 'Sweet Onion Chicken Teriyaki-Wrap', 1880),
#  ('mcdonalds', 'Sweet Onion Sauce-Sauces', 1880),
#  ('mcdonalds', 'Sweet Tea (Child)', 1880),
#  ('mcdonalds', 'Sweet Tea (Large)', 1880),
#  ('mcdonalds', 'Sweet Tea (Medium)', 1880),
#  ('mcdonalds', 'Sweet Tea (Small)', 1880),
#  ('mcdonalds', 'Swiss**-Cheese', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Grande 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Grande Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Short 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Short Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Tall  2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Tall  Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Venti  2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Venti  Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Chai Tea Latte-Venti Nonfat Milk', 1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Grande 2% Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Grande Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Grande Soymilk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Short 2% Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Short Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Short Soymilk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Tall 2% Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Tall Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Tall Soymilk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Venti 2% Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Venti Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)-Venti Soymilk',
#   1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Grande  2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Grande  Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Short 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Short Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Tall 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Tall Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Venti 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Full-Leaf Tea Latte-Venti Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Grande 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Grande Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Grande Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Short 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Short Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Short Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Tall 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Tall Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Venti 2% Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Venti Nonfat Milk', 1880),
#  ('mcdonalds', 'Tazo® Green Tea Latte-Venti Soymilk', 1880),
#  ('mcdonalds', 'Tazo® Tea-Grande', 1880),
#  ('mcdonalds', 'Tazo® Tea-Short', 1880),
#  ('mcdonalds', 'Tazo® Tea-Tall', 1880),
#  ('mcdonalds', 'Tazo® Tea-Venti', 1880),
#  ('mcdonalds', 'The Classic - Bantam Bagels (2 Pack)', 1880),
#  ('mcdonalds', 'Toffeedoodle', 1880),
#  ('mcdonalds', 'Tomato Basil Wrap-Bread', 1880),
#  ('mcdonalds', 'Tomatoes-Veggies', 1880),
#  ('mcdonalds', 'Tuna-Salad', 1880),
#  ('mcdonalds', 'Tuna-Wrap', 1880),
#  ('mcdonalds', 'Turkey & Bacon Guacamole-Sandwich', 1880),
#  ('mcdonalds', 'Turkey & Fire-Roasted Corn Salad', 1880),
#  ('mcdonalds', 'Turkey & Havarti Sandwich', 1880),
#  ('mcdonalds', 'Turkey Breast-Salad', 1880),
#  ('mcdonalds', 'Turkey Breast-Sandwich', 1880),
#  ('mcdonalds', 'Turkey Breast-Wrap', 1880),
#  ('mcdonalds', 'Turkey Pesto Panini', 1880),
#  ('mcdonalds', 'Turkey, Bacon & Guacamole-Wrap', 1880),
#  ('mcdonalds', 'Ultimate Meatball Marinara-Sandwich', 1880),
#  ('mcdonalds', 'Ultimate Spicy Italian-Sandwich', 1880),
#  ('mcdonalds', 'Ultimate Steak-Sandwich', 1880),
#  ('mcdonalds',
#   'Vanilla Bean (Without Whipped Cream)-Grande Nonfat Milk',
#   1880),
#  ('mcdonalds', 'Vanilla Bean (Without Whipped Cream)-Tall  Whole Milk', 1880),
#  ('mcdonalds', 'Vanilla Bean (Without Whipped Cream)-Tall Nonfat Milk', 1880),
#  ('mcdonalds', 'Vanilla Bean (Without Whipped Cream)-Tall Soymilk', 1880),
#  ('mcdonalds', 'Vanilla Bean Whoopie Pie', 1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Grande 2% Milk',
#   1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Grande Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Grande Soymilk',
#   1880),
#  ('mcdonalds', 'Vanilla Latte (Or Other Flavoured Latte)-Short 2% Milk', 1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Short Nonfat Milk',
#   1880),
#  ('mcdonalds', 'Vanilla Latte (Or Other Flavoured Latte)-Short Soymilk', 1880),
#  ('mcdonalds', 'Vanilla Latte (Or Other Flavoured Latte)-Tall  2% Milk', 1880),
#  ('mcdonalds', 'Vanilla Latte (Or Other Flavoured Latte)-Tall  Soymilk', 1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Tall Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Venti  2% Milk',
#   1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Venti  Soymilk',
#   1880),
#  ('mcdonalds',
#   'Vanilla Latte (Or Other Flavoured Latte)-Venti Nonfat Milk',
#   1880),
#  ('mcdonalds', 'Vanilla Shake (Large)', 1880),
#  ('mcdonalds', 'Vanilla Shake (Medium)', 1880),
#  ('mcdonalds', 'Vanilla Shake (Small)', 1880),
#  ('mcdonalds', 'Veggie Delite®-Salad', 1880),
#  ('mcdonalds', 'Veggie Delite®-Sandwich', 1880),
#  ('mcdonalds', 'Veggie Delite®-Wrap', 1880),
#  ('mcdonalds', 'Vermont Maple Walnut Muffin', 1880),
#  ('mcdonalds', 'Volpi™ Pepperoni & Tomato Savory Foldover', 1880),
#  ('mcdonalds', 'White Chip Macadamia Nut Cookie-Extra', 1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Grande 2% Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Grande Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Grande Soymilk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Short 2% Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Short Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Short Soymilk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Tall  2% Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Tall  Soymilk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Tall Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Venti 2% Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Venti Nonfat Milk',
#   1880),
#  ('mcdonalds',
#   'White Chocolate Mocha (Without Whipped Cream)-Venti Soymilk',
#   1880),
#  ('mcdonalds', 'Yellow Mustard-Sauces', 1880),
#  ('mcdonalds', "Za'atar Chicken & Lemon Tahini Salad", 1880),
#  ('subway', '1% Low Fat Milk Jug', 1590),
#  ('subway', '8-Grain Roll', 1590),
#  ('subway', '9-Grain Honey Oat-Bread', 1590),
#  ('subway', '9-Grain Wheat-Bread', 1590),
#  ('subway', 'Almond Croissant', 1590),
#  ('subway', 'American-Cheese', 1590),
#  ('subway', 'Ancho Chipotle Chicken Panini', 1590),
#  ('subway', 'Apple Fritter', 1590),
#  ('subway', 'Apple Slices', 1590),
#  ('subway', 'Artisan Flatbread-Bread', 1590),
#  ('subway', 'BBQ Chicken Protein Box', 1590),
#  ('subway', 'BBQ Rib Signature Wrap-Wrap', 1590),
#  ('subway', 'BBQ Rib-Salad', 1590),
#  ('subway', 'BBQ Rib-Sandwich', 1590),
#  ('subway', 'Bacon Buffalo Ranch McChicken', 1590),
#  ('subway', 'Bacon Cheddar McChicken', 1590),
#  ('subway', 'Bacon Clubhouse Burger', 1590),
#  ('subway', 'Bacon Clubhouse Crispy Chicken Sandwich', 1590),
#  ('subway', 'Bacon Clubhouse Grilled Chicken Sandwich', 1590),
#  ('subway', 'Bacon Gouda & Egg Breakfast Sandwich', 1590),
#  ('subway', 'Bacon McDouble', 1590),
#  ('subway', 'Bacon, Egg & Cheese Bagel', 1590),
#  ('subway', 'Bacon, Egg & Cheese Bagel with Egg Whites', 1590),
#  ('subway', 'Bacon, Egg & Cheese Biscuit (Large Biscuit)', 1590),
#  ('subway', 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)', 1590),
#  ('subway',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)',
#   1590),
#  ('subway',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)',
#   1590),
#  ('subway', 'Bacon, Egg & Cheese McGriddles', 1590),
#  ('subway', 'Bacon, Egg & Cheese McGriddles with Egg Whites', 1590),
#  ('subway', 'Bacon, Egg & Cheese-Breakfast', 1590),
#  ('subway', 'Bacon-Extra', 1590),
#  ('subway', 'Bacon-Extras', 1590),
#  ('subway', 'Bacon-Protein', 1590),
#  ('subway', 'Baked Apple Pie', 1590),
#  ('subway', 'Banana Chocolate Smoothie-Grande 2% Milk', 1590),
#  ('subway', 'Banana Chocolate Smoothie-Grande Nonfat Milk', 1590),
#  ('subway', 'Banana Chocolate Smoothie-Grande Soymilk', 1590),
#  ('subway', 'Banana Nut Bread', 1590),
#  ('subway', 'Banana Peppers-Veggies', 1590),
#  ('subway', 'Berry Trio Yogurt', 1590),
#  ('subway', 'Big Breakfast (Large Biscuit)', 1590),
#  ('subway', 'Big Breakfast (Regular Biscuit)', 1590),
#  ('subway', 'Big Breakfast with Egg Whites (Large Biscuit)', 1590),
#  ('subway', 'Big Breakfast with Egg Whites (Regular Biscuit)', 1590),
#  ('subway', 'Big Breakfast with Hotcakes (Large Biscuit)', 1590),
#  ('subway', 'Big Breakfast with Hotcakes (Regular Biscuit)', 1590),
#  ('subway',
#   'Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)',
#   1590),
#  ('subway',
#   'Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)',
#   1590),
#  ('subway', 'Big Mac', 1590),
#  ('subway', 'Birthday Cake Pop', 1590),
#  ('subway', 'Black Forest Ham, Egg & Cheese-Breakfast', 1590),
#  ('subway', 'Black Forest Ham-Salad', 1590),
#  ('subway', 'Black Forest Ham-Sandwich', 1590),
#  ('subway', 'Black Forest Ham-Wrap', 1590),
#  ('subway', 'Black Olives-Veggies', 1590),
#  ('subway', 'Blueberry Muffin with Yogurt and Honey', 1590),
#  ('subway', 'Blueberry Pomegranate Smoothie (Large)', 1590),
#  ('subway', 'Blueberry Pomegranate Smoothie (Medium)', 1590),
#  ('subway', 'Blueberry Pomegranate Smoothie (Small)', 1590),
#  ('subway', 'Blueberry Scone', 1590),
#  ('subway', 'Brewed Coffee-Grande Coffee', 1590),
#  ('subway', 'Brewed Coffee-Short Coffee', 1590),
#  ('subway', 'Brewed Coffee-Tall Coffee', 1590),
#  ('subway', 'Brewed Coffee-Venti Coffee', 1590),
#  ('subway', 'Buffalo Ranch McChicken', 1590),
#  ('subway', 'Burrata & Basil Pesto Small Sandwich', 1590),
#  ('subway', 'Butter Croissant', 1590),
#  ('subway', 'Butterfly Cookie', 1590),
#  ('subway', 'Caffè Americano-Grande', 1590),
#  ('subway', 'Caffè Americano-Short', 1590),
#  ('subway', 'Caffè Americano-Tall', 1590),
#  ('subway', 'Caffè Americano-Venti', 1590),
#  ('subway', 'Caffè Latte-Grande 2% Milk', 1590),
#  ('subway', 'Caffè Latte-Grande Nonfat Milk', 1590),
#  ('subway', 'Caffè Latte-Grande Soymilk', 1590),
#  ('subway', 'Caffè Latte-Short 2% Milk', 1590),
#  ('subway', 'Caffè Latte-Short Nonfat Milk', 1590),
#  ('subway', 'Caffè Latte-Short Soymilk', 1590),
#  ('subway', 'Caffè Latte-Tall  2% Milk', 1590),
#  ('subway', 'Caffè Latte-Tall  Soymilk', 1590),
#  ('subway', 'Caffè Latte-Tall Nonfat Milk', 1590),
#  ('subway', 'Caffè Latte-Venti 2% Milk', 1590),
#  ('subway', 'Caffè Latte-Venti Nonfat Milk', 1590),
#  ('subway', 'Caffè Latte-Venti Soymilk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Grande  2% Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Grande  Soymilk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Grande Nonfat Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Short 2% Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Short Nonfat Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Short Soymilk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Tall 2% Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Tall Nonfat Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Tall Soymilk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Venti 2% Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Venti Nonfat Milk', 1590),
#  ('subway', 'Caffè Mocha (Without Whipped Cream)-Venti Soymilk', 1590),
#  ('subway', 'Cage-Free Eggs & Seasoned Grains Side Salad', 1590),
#  ('subway', 'Cappuccino-Grande 2% Milk', 1590),
#  ('subway', 'Cappuccino-Grande Nonfat Milk', 1590),
#  ('subway', 'Cappuccino-Grande Soymilk', 1590),
#  ('subway', 'Cappuccino-Short  2% Milk', 1590),
#  ('subway', 'Cappuccino-Short  Soymilk', 1590),
#  ('subway', 'Cappuccino-Short Nonfat Milk', 1590),
#  ('subway', 'Cappuccino-Tall 2% Milk', 1590),
#  ('subway', 'Cappuccino-Tall Nonfat Milk', 1590),
#  ('subway', 'Cappuccino-Tall Soymilk', 1590),
#  ('subway', 'Cappuccino-Venti  2% Milk', 1590),
#  ('subway', 'Cappuccino-Venti  Soymilk', 1590),
#  ('subway', 'Cappuccino-Venti Nonfat Milk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Grande Nonfat Milk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Grande Soymilk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Grande Whole Milk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Tall Nonfat Milk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Tall Soymilk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Tall Whole Milk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Venti  Soymilk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Venti Nonfat Milk', 1590),
#  ('subway', 'Caramel (Without Whipped Cream)-Venti Whole Milk', 1590),
#  ('subway', 'Caramel Apple Cookie-Extra', 1590),
#  ('subway', 'Caramel Apple Spice (Without Whipped Cream)-Grande', 1590),
#  ('subway', 'Caramel Apple Spice (Without Whipped Cream)-Short', 1590),
#  ('subway', 'Caramel Apple Spice (Without Whipped Cream)-Tall', 1590),
#  ('subway', 'Caramel Apple Spice (Without Whipped Cream)-Venti', 1590),
#  ('subway', 'Caramel Iced Coffee (Large)', 1590),
#  ('subway', 'Caramel Iced Coffee (Medium)', 1590),
#  ('subway', 'Caramel Iced Coffee (Small)', 1590),
#  ('subway', 'Caramel Latte (Large)', 1590),
#  ('subway', 'Caramel Latte (Medium)', 1590),
#  ('subway', 'Caramel Latte (Small)', 1590),
#  ('subway', 'Caramel Macchiato-Grande 2% Milk', 1590),
#  ('subway', 'Caramel Macchiato-Grande Nonfat Milk', 1590),
#  ('subway', 'Caramel Macchiato-Grande Soymilk', 1590),
#  ('subway', 'Caramel Macchiato-Short 2% Milk', 1590),
#  ('subway', 'Caramel Macchiato-Short Nonfat Milk', 1590),
#  ('subway', 'Caramel Macchiato-Short Soymilk', 1590),
#  ('subway', 'Caramel Macchiato-Tall  2% Milk', 1590),
#  ('subway', 'Caramel Macchiato-Tall  Soymilk', 1590),
#  ('subway', 'Caramel Macchiato-Tall Nonfat Milk', 1590),
#  ('subway', 'Caramel Macchiato-Venti 2% Milk', 1590),
#  ('subway', 'Caramel Macchiato-Venti Nonfat Milk', 1590),
#  ('subway', 'Caramel Macchiato-Venti Soymilk', 1590),
#  ('subway', 'Caramel Mocha (Large)', 1590),
#  ('subway', 'Caramel Mocha (Medium)', 1590),
#  ('subway', 'Caramel Mocha (Small)', 1590),
#  ('subway', 'Caramel-Grande Nonfat Milk', 1590),
#  ('subway', 'Caramel-Tall Nonfat Milk', 1590),
#  ('subway', 'Caramel-Venti Nonfat Milk', 1590),
#  ('subway', 'Cauliflower Fritter Curry Signature Wrap-Wrap', 1590),
#  ('subway', 'Cauliflower Tabbouleh Side Salad', 1590),
#  ('subway', 'Certified Gluten-Free Breakfast Sandwich', 1590),
#  ('subway', 'Cheddar**-Cheese', 1590),
#  ('subway', 'Cheese & Fruit Protein Box', 1590),
#  ('subway', 'Cheese Danish', 1590),
#  ('subway', 'Cheeseburger', 1590),
#  ('subway', 'Chewy Chocolate Cookie', 1590),
#  ('subway', 'Chicken & Bacon Ranch Melt-Sandwich', 1590),
#  ('subway', 'Chicken & Bacon Ranch Melt-Wrap', 1590),
#  ('subway', 'Chicken & Bacon Ranch-Salad', 1590),
#  ('subway', 'Chicken & Quinoa Protein Bowl with Black Beans and Greens', 1590),
#  ('subway', 'Chicken Artichoke on Ancient Grain Flatbread', 1590),
#  ('subway', 'Chicken BLT Salad Sandwich', 1590),
#  ('subway', 'Chicken Mango Curry-Sandwich', 1590),
#  ('subway', 'Chicken McNuggets (10 piece)', 1590),
#  ('subway', 'Chicken McNuggets (20 piece)', 1590),
#  ('subway', 'Chicken McNuggets (4 piece)', 1590),
#  ('subway', 'Chicken McNuggets (40 piece)', 1590),
#  ('subway', 'Chicken McNuggets (6 piece)', 1590),
#  ('subway', 'Chicken Tikka-Sandwich', 1590),
#  ('subway', 'Chicken Vindaloo-Sandwich', 1590),
#  ('subway', 'Chicken Wrap Protein Box', 1590),
#  ('subway', 'Chipotle BBQ Snack Wrap (Crispy Chicken)', 1590),
#  ('subway', 'Chipotle BBQ Snack Wrap (Grilled Chicken)', 1590),
#  ('subway', 'Chipotle Southwest Steak & Cheese-Wrap', 1590),
#  ('subway', 'Chipotle Southwest-Sauces', 1590),
#  ('subway', 'Chocolate Cake Pop', 1590),
#  ('subway', 'Chocolate Chip Cookie', 1590),
#  ('subway', 'Chocolate Chip Cookie Dough Cake Pop', 1590),
#  ('subway', 'Chocolate Chip Cookie-Extra', 1590),
#  ('subway', 'Chocolate Chip with M&M’s ®-Extra', 1590),
#  ('subway', 'Chocolate Chunk Cookie-Extra', 1590),
#  ('subway', 'Chocolate Chunk Muffin', 1590),
#  ('subway', 'Chocolate Croissant', 1590),
#  ('subway', 'Chocolate Hazelnut Croissant', 1590),
#  ('subway', 'Chocolate Marble Loaf Cake', 1590),
#  ('subway', 'Chocolate Shake (Large)', 1590),
#  ('subway', 'Chocolate Shake (Medium)', 1590),
#  ('subway', 'Chocolate Shake (Small)', 1590),
#  ('subway', 'Chonga Bagel', 1590),
#  ('subway', 'Cinnamon Melts', 1590),
#  ('subway', 'Cinnamon Morning Bun', 1590),
#  ('subway', 'Cinnamon Raisin Bagel', 1590),
#  ('subway', 'Classic Coffee Cake', 1590),
#  ('subway', 'Classic Tuna-Sandwich', 1590),
#  ('subway', 'Classic Whole-Grain Oatmeal', 1590),
#  ('subway', 'Coca-Cola Classic (Child)', 1590),
#  ('subway', 'Coca-Cola Classic (Large)', 1590),
#  ('subway', 'Coca-Cola Classic (Medium)', 1590),
#  ('subway', 'Coca-Cola Classic (Small)', 1590),
#  ('subway', 'Coffee (Large)', 1590),
#  ('subway', 'Coffee (Medium)', 1590),
#  ('subway', 'Coffee (Small)', 1590),
#  ('subway', 'Coffee-Grande Nonfat Milk', 1590),
#  ('subway', 'Coffee-Grande Soymilk', 1590),
#  ('subway', 'Coffee-Grande Whole Milk', 1590),
#  ('subway', 'Coffee-Tall Nonfat Milk', 1590),
#  ('subway', 'Coffee-Tall Soymilk', 1590),
#  ('subway', 'Coffee-Tall Whole Milk', 1590),
#  ('subway', 'Coffee-Venti  Soymilk', 1590),
#  ('subway', 'Coffee-Venti Nonfat Milk', 1590),
#  ('subway', 'Coffee-Venti Whole Milk', 1590),
#  ('subway', 'Cold Cut Combo-Salad', 1590),
#  ('subway', 'Cold Cut Combo-Sandwich', 1590),
#  ('subway', 'Cold Cut Combo-Wrap', 1590),
#  ('subway', 'Cookie Butter Bar', 1590),
#  ('subway', 'Cranberry Orange Scone', 1590),
#  ('subway', 'Cripsy Cauliflower Ranch Signature Wrap-Wrap', 1590),
#  ('subway', 'Cubano Sandwich', 1590),
#  ('subway', 'Cucumbers-Veggies', 1590),
#  ('subway', 'Daily Double', 1590),
#  ('subway', 'Dark Chocolate Cherry Cookie-Extra', 1590),
#  ('subway', 'Dasani Water Bottle', 1590),
#  ('subway', "Devil's Food Doughnut", 1590),
#  ('subway', 'Diet Coke (Child)', 1590),
#  ('subway', 'Diet Coke (Large)', 1590),
#  ('subway', 'Diet Coke (Medium)', 1590),
#  ('subway', 'Diet Coke (Small)', 1590),
#  ('subway', 'Diet Dr Pepper (Child)', 1590),
#  ('subway', 'Diet Dr Pepper (Large)', 1590),
#  ('subway', 'Diet Dr Pepper (Medium)', 1590),
#  ('subway', 'Diet Dr Pepper (Small)', 1590),
#  ('subway', 'Double Cheeseburger', 1590),
#  ('subway', 'Double Chocolate Brownie', 1590),
#  ('subway', 'Double Chocolate Chunk Brownie', 1590),
#  ('subway', 'Double Chocolate Loaf Cake', 1590),
#  ('subway', 'Double Chocolate-Extra', 1590),
#  ('subway', 'Double Quarter Pounder with Cheese', 1590),
#  ('subway', 'Double-Smoked Bacon Cheddar & Egg Sandwich', 1590),
#  ('subway', 'Dr Pepper (Child)', 1590),
#  ('subway', 'Dr Pepper (Large)', 1590),
#  ('subway', 'Dr Pepper (Medium)', 1590),
#  ('subway', 'Dr Pepper (Small)', 1590),
#  ('subway', 'Egg & Cheese-Breakfast', 1590),
#  ('subway', 'Egg McMuffin', 1590),
#  ('subway', 'Egg Salad Sandwich', 1590),
#  ('subway', 'Egg White Delight', 1590),
#  ('subway', 'Eggs & Cheese Protein Box', 1590),
#  ('subway', 'Espresso-Doppio', 1590),
#  ('subway', 'Espresso-Solo', 1590),
#  ('subway', "Everybody's Favorite - Bantam Bagel (2 Pack)", 1590),
#  ('subway', 'Everything Bagel with Cheese', 1590),
#  ...]

# %%
# Find breakfast items with more than 400 calories at each restaurant 
# (restaurants + menu_items + nutrition tables)

sel = [Restaurants.name, Menu_items.item_name, Nutrition.restaurant_id, Nutrition.calories]

breakfast_calories = session.query(*sel).filter(Nutrition.restaurant_id==Restaurants.id).\
filter(Nutrition.category_id==Categories.id).\
filter(Categories.category_name=="Breakfast").\
filter(Nutrition.item_id==Menu_items.id).\
filter(Nutrition.calories > 400).\
order_by(Nutrition.calories.desc()).all()

breakfast_calories
# Out:
# [('mcdonalds', 'Big Breakfast with Hotcakes (Large Biscuit)', 1000, 1150),
#  ('mcdonalds', 'Big Breakfast with Hotcakes (Regular Biscuit)', 1000, 1090),
#  ('mcdonalds',
#   'Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)',
#   1000,
#   1050),
#  ('mcdonalds',
#   'Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)',
#   1000,
#   990),
#  ('mcdonalds', 'Big Breakfast (Large Biscuit)', 1000, 800),
#  ('mcdonalds', 'Big Breakfast (Regular Biscuit)', 1000, 740),
#  ('mcdonalds', 'Big Breakfast with Egg Whites (Large Biscuit)', 1000, 690),
#  ('mcdonalds', 'Steak, Egg & Cheese Bagel', 1000, 670),
#  ('mcdonalds', 'Big Breakfast with Egg Whites (Regular Biscuit)', 1000, 640),
#  ('mcdonalds', 'Bacon, Egg & Cheese Bagel', 1000, 620),
#  ('mcdonalds', 'Sausage Biscuit with Egg (Large Biscuit)', 1000, 570),
#  ('mcdonalds', 'Bacon, Egg & Cheese Bagel with Egg Whites', 1000, 570),
#  ('mcdonalds', 'Sausage, Egg & Cheese McGriddles', 1000, 550),
#  ('mcdonalds', 'Steak & Egg Biscuit (Regular Biscuit)', 1000, 540),
#  ('mcdonalds', 'Bacon, Egg & Cheese Biscuit (Large Biscuit)', 1000, 520),
#  ('mcdonalds', 'Sausage Biscuit with Egg Whites (Large Biscuit)', 1000, 520),
#  ('mcdonalds', 'Hotcakes and Sausage', 1000, 520),
#  ('mcdonalds', 'Sausage Biscuit with Egg (Regular Biscuit)', 1000, 510),
#  ('mcdonalds', 'Sausage, Egg & Cheese McGriddles with Egg Whites', 1000, 500),
#  ('starbucks', 'Sausage Cheddar & Egg Breakfast Sandwich', 3000, 500),
#  ('starbucks',
#   'Spicy Chorizo  Monterey Jack & Egg Breakfast Sandwich',
#   3000,
#   500),
#  ('starbucks', 'Double-Smoked Bacon Cheddar & Egg Sandwich', 3000, 490),
#  ('mcdonalds', 'Sausage Biscuit (Large Biscuit)', 1000, 480),
#  ('starbucks', 'Old-Fashioned Glazed Doughnut', 3000, 480),
#  ('mcdonalds',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)',
#   1000,
#   470),
#  ('mcdonalds', 'Southern Style Chicken Biscuit (Large Biscuit)', 1000, 470),
#  ('mcdonalds', 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)', 1000, 460),
#  ('mcdonalds', 'Sausage Biscuit with Egg Whites (Regular Biscuit)', 1000, 460),
#  ('mcdonalds', 'Bacon, Egg & Cheese McGriddles', 1000, 460),
#  ('mcdonalds', 'Cinnamon Melts', 1000, 460),
#  ('starbucks', 'Apple Fritter', 3000, 460),
#  ('starbucks', 'Eggs & Cheese Protein Box', 3000, 460),
#  ('mcdonalds', 'Sausage McMuffin with Egg', 1000, 450),
#  ('subway', 'Bacon, Egg & Cheese-Breakfast', 2000, 450),
#  ('starbucks', 'Slow-Roasted Ham Swiss & Egg Breakfast Sandwich', 3000, 450),
#  ('subway', 'Steak, Egg & Cheese-Breakfast', 2000, 440),
#  ('starbucks', 'Chocolate Chunk Muffin', 3000, 440),
#  ('mcdonalds', 'Steak & Egg McMuffin', 1000, 430),
#  ('mcdonalds', 'Sausage Biscuit (Regular Biscuit)', 1000, 430),
#  ('starbucks', "Devil's Food Doughnut", 3000, 430),
#  ('mcdonalds', 'Sausage McGriddles', 1000, 420),
#  ('starbucks', 'Banana Nut Bread', 3000, 420),
#  ('starbucks', 'Blueberry Scone', 3000, 420),
#  ('starbucks', 'Cranberry Orange Scone', 3000, 420),
#  ('starbucks', 'Raspberry Swirl Loaf Cake', 3000, 420),
#  ('mcdonalds',
#   'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)',
#   1000,
#   410),
#  ('mcdonalds', 'Southern Style Chicken Biscuit (Regular Biscuit)', 1000, 410),
#  ('subway', 'Black Forest Ham, Egg & Cheese-Breakfast', 2000, 410),
#  ('starbucks', 'Almond Croissant', 3000, 410),
#  ('starbucks', 'Pumpkin Bread', 3000, 410),
#  ('starbucks', 'Seared Steak Egg & Tomatillo Wrap', 3000, 410)]
